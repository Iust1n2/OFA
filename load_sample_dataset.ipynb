# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('dataset/vision_language_examples.tsv', delimiter='\t')
data2 = pd.read_csv('dataset/image_examples.tsv', delimiter='\t')
data3 = pd.read_csv('dataset/text_examples.tsv', delimiter='\t')
data4 = pd.read_csv('dataset/detection_examples.tsv', delimiter='\t')

# %%
# data1.head(1)
data1.columns
# Out:
# Index(['6334649',
#        '...',
#        'fishing on the rocks near garrison point', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'cc12m', 'caption'],
#       dtype='object')

# %%
# data2.head(1)
data2.columns
# Out:
# Index(['1',
#        '...',
# ...

# %%
data3.head(1)
# data3.columns
# Out:
#    1  \
# 0  2
#
# ...

# %%
# data4.head(1)
data4.columns
# Out:
# Index(['1',
#        '...',
#        '505.856,189.994,799.744,450.016,/m/07j7r,tree&&753.664,384.00600000000003,827.392,446.572,/m/0c9ph5,flower&&61.44,175.07,103.424,209.51,/m/0c9ph5,flower&&979.968,260.596,1012.736,301.35,/m/0c9ph5,flower&&22.528,0.0,68.608,28.126,/m/0c9ph5,flower&&944.128,227.87800000000001,971.776,261.744,/m/0c9ph5,flower&&917.504,284.13,953.344,304.22,/m/0c9ph5,flower&&11.264,82.65599999999999,28.672,111.35600000000001,/m/0c9ph5,flower'],
#       dtype='object')
